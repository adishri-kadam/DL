# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Loading the dataset

# %%
train_df = pd.read_csv('Google_Stock_Price_Train.csv')
test_df = pd.read_csv('Google_Stock_Price_Test.csv')
train_df.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %% [markdown]
# #### Choosing column 'open' for predicition

# %%
train = train_df.loc[:,['Open']].values
train.shape
train
# Out:
# array([[325.25],
#        [331.27],
#        [329.83],
#        ...,
#        [793.7 ],
#        [783.33],
#        [782.75]])

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
train_scaled = scaler.fit_transform(train)

# %%
plt.plot(train_scaled)
plt.ylabel("Standardized Values")
plt.xlabel("Time->")
plt.show()

# %% [markdown]
# ### Create data structure to train model
# Taking reference of past 60 days to predict future stock price
# x_train will have data of 60 days prior to current date and y_train will have price on current date

# %%
x_train = []
y_train = []
time = 60
for i in range(60,train_scaled.shape[0]):
    x_train.append(train_scaled[i-60:i,0])
    y_train.append(train_scaled[i,0])
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
x_train.shape,y_train.shape
# Out:
# ((1198, 60), (1198,))

# %%
x_train = np.reshape(x_train,newshape=(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (1198, 60, 1)

# %% [markdown]
# ### Build model

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN,Dropout

# %%
model = Sequential()

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50))
model.add(Dropout(0.2))

model.add(Dense(units=1))

model.compile(optimizer='adam',loss='mse')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_4 (SimpleRNN)    (None, 60, 50)            2600
#
#  dropout_4 (Dropout)         (None, 60, 50)            0
#
#  simple_rnn_5 (SimpleRNN)    (None, 60, 50)            5050
#
#  dropout_5 (Dropout)         (None, 60, 50)            0
#
#  simple_rnn_6 (SimpleRNN)    (None, 60, 50)            5050
#
#  dropout_6 (Dropout)         (None, 60, 50)            0
#
#  simple_rnn_7 (SimpleRNN)    (None, 50)                5050
#
#  dropout_7 (Dropout)         (None, 50)                0
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 17801 (69.54 KB)
# Trainable params: 17801 (69.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=100,batch_size=30,validation_split=0.05)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 6s 52ms/step - loss: 0.5281 - val_loss: 0.0729
# Epoch 2/100
# 38/38 [==============================] - 1s 38ms/step - loss: 0.3028 - val_loss: 0.0047
# Epoch 3/100
# 38/38 [==============================] - 1s 37ms/step - loss: 0.2804 - val_loss: 0.0051
# Epoch 4/100
# 38/38 [==============================] - 1s 38ms/step - loss: 0.2335 - val_loss: 0.0348
# Epoch 5/100
# 38/38 [==============================] - 1s 36ms/step - loss: 0.1844 - val_loss: 0.0392
# Epoch 6/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.1428 - val_loss: 0.0131
# Epoch 7/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.1351 - val_loss: 0.0023
# Epoch 8/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0970 - val_loss: 0.0088
# Epoch 9/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0799 - val_loss: 0.0121
# Epoch 10/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0732 - val_loss: 0.0043
# Epoch 11/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0564 - val_loss: 0.0011
# Epoch 12/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0552 - val_loss: 0.0073
# Epoch 13/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0445 - val_loss: 0.0235
# Epoch 14/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0426 - val_loss: 0.0012
# Epoch 15/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0392 - val_loss: 0.0019
# Epoch 16/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0342 - val_loss: 0.0120
# Epoch 17/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0333 - val_loss: 0.0239
# Epoch 18/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0279 - val_loss: 0.0049
# Epoch 19/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0273 - val_loss: 0.0029
# Epoch 20/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0223 - val_loss: 6.4237e-04
# Epoch 21/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0216 - val_loss: 0.0044
# Epoch 22/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0183 - val_loss: 0.0082
# Epoch 23/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0189 - val_loss: 0.0022
# Epoch 24/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0164 - val_loss: 0.0044
# Epoch 25/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0146 - val_loss: 0.0020
# Epoch 26/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0142 - val_loss: 0.0015
# Epoch 27/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0139 - val_loss: 0.0038
# Epoch 28/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0136 - val_loss: 0.0032
# Epoch 29/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0121 - val_loss: 0.0044
# Epoch 30/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0122 - val_loss: 0.0032
# Epoch 31/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0120 - val_loss: 0.0050
# Epoch 32/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0112 - val_loss: 8.8912e-04
# Epoch 33/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0102 - val_loss: 9.8347e-04
# Epoch 34/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0095 - val_loss: 0.0014
# Epoch 35/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0085 - val_loss: 6.4908e-04
# Epoch 36/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0090 - val_loss: 0.0017
# Epoch 37/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0083 - val_loss: 0.0080
# Epoch 38/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0083 - val_loss: 0.0015
# Epoch 39/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0074 - val_loss: 6.7248e-04
# Epoch 40/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0071 - val_loss: 0.0025
# Epoch 41/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0069 - val_loss: 0.0011
# Epoch 42/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0063 - val_loss: 6.1745e-04
# Epoch 43/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0069 - val_loss: 8.5459e-04
# Epoch 44/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0071 - val_loss: 0.0020
# Epoch 45/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0061 - val_loss: 0.0044
# Epoch 46/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0060 - val_loss: 6.2719e-04
# Epoch 47/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0060 - val_loss: 8.4738e-04
# Epoch 48/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0061 - val_loss: 0.0010
# Epoch 49/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0058 - val_loss: 7.3223e-04
# Epoch 50/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0051 - val_loss: 8.9581e-04
# Epoch 51/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0046 - val_loss: 0.0022
# Epoch 52/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0049 - val_loss: 0.0022
# Epoch 53/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0051 - val_loss: 5.6724e-04
# Epoch 54/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0049 - val_loss: 5.9546e-04
# Epoch 55/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0042 - val_loss: 5.6803e-04
# Epoch 56/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0048 - val_loss: 0.0014
# Epoch 57/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0047 - val_loss: 0.0027
# Epoch 58/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0043 - val_loss: 0.0027
# Epoch 59/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 60/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0043 - val_loss: 6.0463e-04
# Epoch 61/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0042 - val_loss: 5.7095e-04
# Epoch 62/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0037 - val_loss: 7.4200e-04
# Epoch 63/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0036 - val_loss: 9.4294e-04
# Epoch 64/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0038 - val_loss: 6.4880e-04
# Epoch 65/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0035 - val_loss: 7.4334e-04
# Epoch 66/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0039 - val_loss: 9.9482e-04
# Epoch 67/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0036 - val_loss: 7.7264e-04
# Epoch 68/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0035 - val_loss: 0.0011
# Epoch 69/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0034 - val_loss: 5.3840e-04
# Epoch 70/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 71/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0033 - val_loss: 7.2042e-04
# Epoch 72/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0034 - val_loss: 5.9309e-04
# Epoch 73/100
# 38/38 [==============================] - 1s 29ms/step - loss: 0.0033 - val_loss: 5.8409e-04
# Epoch 74/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 75/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0030 - val_loss: 7.0532e-04
# Epoch 76/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0031 - val_loss: 5.3041e-04
# Epoch 77/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0030 - val_loss: 5.3584e-04
# Epoch 78/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 79/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0030 - val_loss: 6.7942e-04
# Epoch 80/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0027 - val_loss: 6.8706e-04
# Epoch 81/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 82/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0027 - val_loss: 0.0014
# Epoch 83/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0030 - val_loss: 5.2316e-04
# Epoch 84/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0027 - val_loss: 9.2810e-04
# Epoch 85/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0028 - val_loss: 5.2095e-04
# Epoch 86/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0027 - val_loss: 5.4537e-04
# Epoch 87/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0025 - val_loss: 8.0692e-04
# Epoch 88/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 89/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0025 - val_loss: 5.6879e-04
# Epoch 90/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0022 - val_loss: 5.2778e-04
# Epoch 91/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0025 - val_loss: 5.4431e-04
# Epoch 92/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0028 - val_loss: 9.6484e-04
# Epoch 93/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0026 - val_loss: 0.0011
# Epoch 94/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0025 - val_loss: 8.4803e-04
# Epoch 95/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0025 - val_loss: 7.0874e-04
# Epoch 96/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0022 - val_loss: 5.4294e-04
# Epoch 97/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0022 - val_loss: 5.4764e-04
# Epoch 98/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0024 - val_loss: 5.2544e-04
# Epoch 99/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0022 - val_loss: 6.5240e-04
# Epoch 100/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0023 - val_loss: 7.3584e-04

# %% [markdown]
# ### Prepare test dataset

# %%
data = pd.concat((train_df['Open'],test_df['Open']),axis=0)

# %%
test_input = data.iloc[len(data) - len(test_df) - time : ].values
test_input.shape
# Out:
# (80,)

# %%
test_input = test_input.reshape(-1,1)
test_input.shape
# Out:
# (80, 1)

# %%
test_scaled = scaler.transform(test_input)

# %% [markdown]
# #### Create test data set

# %%
x_test = []
for i in range(time,test_scaled.shape[0]):
    x_test.append(test_scaled[i - time: i,0 ])
x_test = np.array(x_test)
x_test.shape
# Out:
# (20, 60)

# %%
x_test = np.reshape(x_test,newshape=(x_test.shape[0],x_test.shape[1],1))
x_test.shape
# Out:
# (20, 60, 1)

# %%
y_test = test_df.loc[:,"Open"].values

# %% [markdown]
# ### Model Prediction

# %%
y_pred = model.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 360ms/step

# %%
y_pred = scaler.inverse_transform(y_pred)

# %%
output = model.evaluate(x=x_test,y=y_test)
# Out:
# 1/1 [==============================] - 0s 369ms/step - loss: 650798.5000

# %%
plt.plot(y_test, color = 'red', label = 'Real price')
plt.plot(y_pred, color = 'blue', label = 'Predicted price')

plt.title('Google Stock price prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
